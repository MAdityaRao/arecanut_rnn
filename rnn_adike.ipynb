# %%
import os
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'

import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import SimpleRNN, Dense, Dropout
import joblib

# --- 1. Load and Prepare Data ---
df = pd.read_csv("arecanut.csv")
df['Price Date'] = pd.to_datetime(df['Price Date'])
df.sort_values('Price Date', inplace=True)
price_data = df[['Max Price (Rs./Quintal)']].values

# --- 2. Scale the Data ---
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(price_data)

# --- 3. Create Sequences ---
SEQUENCE_LENGTH = 30
train_size = int(len(scaled_data) * 0.8)
train_data = scaled_data[:train_size]
test_data = scaled_data[train_size - SEQUENCE_LENGTH:]

X_train, y_train, X_test, y_test = [], [], [], []

for i in range(SEQUENCE_LENGTH, len(train_data)):
    X_train.append(train_data[i - SEQUENCE_LENGTH:i, 0])
    y_train.append(train_data[i, 0])

for i in range(SEQUENCE_LENGTH, len(test_data)):
    X_test.append(test_data[i - SEQUENCE_LENGTH:i, 0])
    y_test.append(test_data[i, 0])

X_train, y_train = np.array(X_train), np.array(y_train)
X_test, y_test = np.array(X_test), np.array(y_test)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

print(f"Training samples: {X_train.shape[0]}")
print(f"Testing samples: {X_test.shape[0]}")

# --- 4. Build and Train the RNN Model ---
with tf.device('/GPU:0'):
    model = Sequential([
    SimpleRNN(50, return_sequences=True, input_shape=(X_train.shape[1], 1), unroll=True),
    Dropout(0.2),
    SimpleRNN(50, return_sequences=False, unroll=True),
    Dropout(0.2),
    Dense(25, activation='relu'),
    Dense(1)
])

    model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

    print("\nTraining RNN Model")
    history = model.fit(X_train, y_train,
                        epochs=100,
                        batch_size=32,
                        verbose=1,
                        validation_data=(X_test, y_test))

# --- 5. Evaluate Model ---
train_loss, train_mae = model.evaluate(X_train, y_train, verbose=0)
test_loss, test_mae = model.evaluate(X_test, y_test, verbose=0)

print(f"\n--- Model Performance ---")
print(f"Train Loss: {train_loss:.4f}, Train MAE: {train_mae:.4f}")
print(f"Test Loss: {test_loss:.4f}, Test MAE: {test_mae:.4f}")

# --- 6. Save Model, Scaler, and Test Data ---
model.save('model_adike.keras')
joblib.dump(scaler, 'scaler_adike.gz')

print("\n--- Files Saved ---")
print("Model saved as 'model_adike.keras'")
print("Scaler saved as 'scaler_adike.gz'")
# Out:
# Training samples: 2713
# Testing samples: 686
# 2026-06-23 12:52:04.514499: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1
# 2026-06-23 12:52:04.514535: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2026-06-23 12:52:04.514552: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2026-06-23 12:52:04.514590: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2026-06-23 12:52:04.514615: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Training RNN Model
# Epoch 1/100
# 2026-06-23 12:52:07.335868: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 85/85 [==============================] - 16s 112ms/step - loss: 0.1430 - mae: 0.2947 - val_loss: 0.0033 - val_mae: 0.0362
# Epoch 2/100
# 85/85 [==============================] - 5s 59ms/step - loss: 0.0909 - mae: 0.2387 - val_loss: 0.0805 - val_mae: 0.2747
# Epoch 3/100
# 85/85 [==============================] - 5s 58ms/step - loss: 0.0567 - mae: 0.1894 - val_loss: 0.0040 - val_mae: 0.0463
# Epoch 4/100
# 85/85 [==============================] - 7s 80ms/step - loss: 0.0206 - mae: 0.1144 - val_loss: 0.0097 - val_mae: 0.0871
# Epoch 5/100
# 85/85 [==============================] - 9s 105ms/step - loss: 0.0101 - mae: 0.0787 - val_loss: 0.0031 - val_mae: 0.0371
# Epoch 6/100
# 85/85 [==============================] - 7s 88ms/step - loss: 0.0075 - mae: 0.0689 - val_loss: 0.0064 - val_mae: 0.0646
# Epoch 7/100
# 85/85 [==============================] - 8s 91ms/step - loss: 0.0494 - mae: 0.1513 - val_loss: 0.0508 - val_mae: 0.1872
# Epoch 8/100
# 85/85 [==============================] - 8s 93ms/step - loss: 0.0493 - mae: 0.1749 - val_loss: 0.1447 - val_mae: 0.3590
# Epoch 9/100
# 85/85 [==============================] - 7s 87ms/step - loss: 0.0377 - mae: 0.1518 - val_loss: 0.1232 - val_mae: 0.3297
# Epoch 81/100
# 85/85 [==============================] - 5s 54ms/step - loss: 0.0076 - mae: 0.0680 - val_loss: 0.0143 - val_mae: 0.0932
# Epoch 82/100
# 85/85 [==============================] - 5s 53ms/step - loss: 0.0089 - mae: 0.0733 - val_loss: 0.0162 - val_mae: 0.1039
# Epoch 83/100
# 85/85 [==============================] - 4s 53ms/step - loss: 0.0081 - mae: 0.0707 - val_loss: 0.0147 - val_mae: 0.0871
# Epoch 84/100
# 85/85 [==============================] - 4s 50ms/step - loss: 0.0080 - mae: 0.0701 - val_loss: 0.0143 - val_mae: 0.0965
# Epoch 85/100
# 85/85 [==============================] - 4s 52ms/step - loss: 0.0082 - mae: 0.0709 - val_loss: 0.0147 - val_mae: 0.0968
# Epoch 86/100
# 85/85 [==============================] - 4s 48ms/step - loss: 0.0075 - mae: 0.0679 - val_loss: 0.0100 - val_mae: 0.0744
# Epoch 87/100
# 85/85 [==============================] - 4s 48ms/step - loss: 0.0078 - mae: 0.0693 - val_loss: 0.0131 - val_mae: 0.0908
# Epoch 88/100
# 85/85 [==============================] - 4s 50ms/step - loss: 0.0071 - mae: 0.0662 - val_loss: 0.0154 - val_mae: 0.0973
# Epoch 89/100
# 85/85 [==============================] - 4s 48ms/step - loss: 0.0080 - mae: 0.0701 - val_loss: 0.0119 - val_mae: 0.0787
# Epoch 90/100
# 73/85 [========================>.....] - ETA: 0s - loss: 0.0074 - mae: 0.0669

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, r2_score

# --- 2. Predict on both train and test ---
y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)

# --- 3. Inverse Transform ---
y_pred_train_inv = scaler.inverse_transform(y_pred_train)
y_train_inv = scaler.inverse_transform(y_train.reshape(-1, 1))
y_pred_test_inv = scaler.inverse_transform(y_pred_test)
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))

# --- 4. Combine ---
actual = np.concatenate([y_train_inv, y_test_inv])
predicted = np.concatenate([y_pred_train_inv, y_pred_test_inv])

df = pd.read_csv("arecanut.csv")
df['Price Date'] = pd.to_datetime(df['Price Date'])
df.sort_values('Price Date', inplace=True)
dates = df['Price Date'].values[SEQUENCE_LENGTH:]

# --- 5. Plot ---
plt.style.use('seaborn-v0_8-whitegrid')
plt.figure(figsize=(16, 7))
plt.plot(dates, actual, color='#1f77b4', linewidth=1.5, label='Actual Price (₹)')
plt.plot(dates, predicted, color='#ff7f0e', linewidth=1.5, linestyle='--', label='Predicted Price (₹)')
plt.fill_between(dates, actual.ravel(), predicted.ravel(), color='orange', alpha=0.1)
plt.title('Adike Price - Actual vs Predicted (Full Timeline) RNN', fontsize=16, fontweight='bold', pad=15)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Price (Rs./Quintal)', fontsize=12)
plt.xticks(rotation=45)
plt.legend(frameon=True, fontsize=11, loc='best', shadow=True)
plt.grid(alpha=0.3, linestyle='--')
plt.tight_layout()
plt.show()

# --- 6. Metrics ---
mae = mean_absolute_error(y_test_inv, y_pred_test_inv)
r2 = r2_score(y_test_inv, y_pred_test_inv)
print(f"\nMean Absolute Error (MAE): RNN_Adike {mae:.2f}")
print(f"R² Score: RNN_Adike {r2:.4f}")
# Out:
# 85/85 [==============================] - 4s 48ms/step
# 22/22 [==============================] - 1s 35ms/step
# /var/folders/ls/k1p_ptn500g_fx4qdb8780cc0000gp/T/ipykernel_46826/3629803163.py:37: UserWarning: Glyph 8377 (\N{INDIAN RUPEE SIGN}) missing from current font.
#   plt.tight_layout()
# /Users/adityarao/Desktop/arecanut_rnn/.venv/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 8377 (\N{INDIAN RUPEE SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# Mean Absolute Error (MAE): 4141.59
# R² Score: 0.2186
